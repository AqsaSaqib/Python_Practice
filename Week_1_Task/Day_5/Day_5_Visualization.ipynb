# %% [markdown]
# # **Conceptual Questions**

# %%
# 1. When would you use a bar chart vs. a histogram?
"""
A bar chat is used to compare values between different categories and A Histogram is used to compare the distribution of a numerical values
Bar chart is used for categorical values and Histogram is used for Numerical Values
"""

# %%
#2. What is the difference between plt.plot() and sns.lineplot()?
"""
plt.plot is used to draw a line chart in matplotlib and it's a simple way to draw a line chart
whereas sns.lineplot is a seaborn line chart which is used to draw a line chart and it works more efficiently with dataframes
"""

# %%
# 3. What does a boxplot actually show — what are the whiskers?
"""
A box plot is mainly used to shows the distribution of numerical values. The line in the middle of box shows the median value.
And whiskers are the Normal range in which values lies and the line above and below the box are whiskers.
"""

# %%
# 4. How do you plot multiple charts in one figure using Matplotlib?
"""
We use subplot() in matplotlib to create multiple charts in one figure.
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
"""

# %%
# 5. What is a heatmap useful for and what kind of data does it work best with?
"""
A heatmap shows different color to shows the numeric values. It is speacially used to shows correlation between them.
A correlation ranges from +1 to -1. 0 shows no correlation. +1 shows positive correlation and -1 shows negative correlation.
"""

# %% [markdown]
# # **Implementation Task**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/Superstore.csv", encoding="latin1")

# %% [markdown]
# # **Plot a histogram of the main numeric column**

# %%
plt.figure(figsize=(9, 5))
sns.histplot(data=df, x="Sales", bins=30, kde=True)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Number of Orders")
plt.show()

# %% [markdown]
# # **Plot a bar chart showing average value grouped by a category column**

# %%
avg_sales = df.groupby("Category")["Sales"].mean().sort_values(ascending=False)
plt.figure(figsize=(9, 5))
sns.barplot(x=avg_sales.index, y=avg_sales.values)
plt.title("Average Sales by Category")
plt.xlabel("Category")
plt.ylabel("Average Sales")
plt.show()

# %% [markdown]
# # **Plot a boxplot to visualize the distribution and spot outliers visually**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df,x="Sales",width=0.5,linewidth=2)
plt.title("Sales Distribution and Outliers")
plt.xlabel("Sales Amount")
plt.ylabel("Distribution")
plt.grid(axis="x", linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# # **Plot a correlation heatmap of all numeric columns using Seaborn**

# %%
numeric_df = df.select_dtypes(include="number")
correlation = numeric_df.corr()
plt.figure(figsize=(10, 7))
sns.heatmap(correlation,annot=True,fmt=".2f",cmap="coolwarm",center=0,linewidths=0.5,square=True)
plt.title("Correlation Heatmap - Superstore Dataset")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.show()
